# %%
#Using dictionary to create a series
import pandas as pd
car_price_dict = {'Swift':  700000,
                        'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)
car_price
pd.DataFrame(car_price, columns=['Car Price'])
# Out:
#           Car Price
# Swift        700000
# Jazz         800000
# Civic       1600000
# Altis       1800000
# Gallardo   30000000

# %%
series = pd.Series(data = [78, 92, 36, 64, 89])  
series
# Out:
# 0    78
# 1    92
# 2    36
# 3    64
# 4    89
# dtype: int64

# %%
series.values
# Out:
# array([78, 92, 36, 64, 89], dtype=int64)

# %%
series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
series[1]
# Out:
# 92

# %%
series[1:4]
# Out:
# 1    92
# 2    36
# 3    64
# dtype: int64

# %%
import pandas as pd
data=[{'name':'subodh','marks':28},
     {'name':'ram','marks':27},
     {'name':'abdul','marks':28},
        {'name':'john','marks':28}]
pd.DataFrame(data)
# Out:
#      name  marks
# 0  subodh     28
# 1     ram     27
# 2   abdul     28
# 3    john     28

# %%
pd.DataFrame([{'subodh':20,'ram':25},
             {'abdul':29,'john':24}],
             index=['mathematics','physics'])
# Out:
#              subodh   ram  abdul  john
# mathematics    20.0  25.0    NaN   NaN
# physics         NaN   NaN   29.0  24.0

# %%
car_price_dict = {'Swift':  700000,
                       'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)
car_man_dict = {'Swift' : 'Maruti',
                  'Jazz'   : 'Honda',
                  'Civic'  : 'Honda',
                  'Altis'  : 'Toyota',
                   'Gallardo' : 'Lamborghini'}
car_man = pd.Series(car_man_dict)
cars = pd.DataFrame({'Price': car_price , 'Manufacturer' : car_man})
cars
# Out:
#              Price Manufacturer
# Swift       700000       Maruti
# Jazz        800000        Honda
# Civic      1600000        Honda
# Altis      1800000       Toyota
# Gallardo  30000000  Lamborghini

# %%
data=pd.Series(data=[700000,800000,1600000,1800000,3000000], index=['swift','jazz','civic','altis','gallardo'])
data
# Out:
# swift        700000
# jazz         800000
# civic       1600000
# altis       1800000
# gallardo    3000000
# dtype: int64

# %%
data['swift']
# Out:
# 700000

# %%
data['jazz': 'gallardo']
# Out:
# jazz         800000
# civic       1600000
# altis       1800000
# gallardo    3000000
# dtype: int64

# %%
import pandas as pd
df =pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.head(8)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# 5       1           ford galaxie 500
# 6       1           chevrolet impala
# 7       1          plymouth fury iii

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin             name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
df.tail(7)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 391  36.0          4         135.0         84    2370          13.0
# 392  27.0          4         151.0         90    2950          17.3
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin               name
# 391          82       1  dodge charger 2.2
# 392          82       1   chevrolet camaro
# 393          82       1    ford mustang gl
# 394          82       2          vw pickup
# 395          82       1      dodge rampage
# 396          82       1        ford ranger
# 397          82       1         chevy s-10

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397 entries, 1 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   model_year    397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 31.0+ KB

# %%
df[['name', 'origin', 'model_year', 'mpg']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397 entries, 1 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   model_year    397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 31.0+ KB

# %%
df['name']
# Out:
# 1       buick skylark 320
# 2      plymouth satellite
# 3           amc rebel sst
# 4             ford torino
# 5        ford galaxie 500
#               ...
# 393       ford mustang gl
# 394             vw pickup
# 395         dodge rampage
# 396           ford ranger
# 397            chevy s-10
# Name: name, Length: 397, dtype: object

# %%
df[['name']]
# Out:
#                    name
# 1     buick skylark 320
# 2    plymouth satellite
# 3         amc rebel sst
# 4           ford torino
# 5      ford galaxie 500
# ..                  ...
# 393     ford mustang gl
# 394           vw pickup
# 395       dodge rampage
# 396         ford ranger
# 397          chevy s-10
#
# [397 rows x 1 columns]

# %%
df[['name', 'origin', 'model_year', 'mpg','horsepower']]
# Out:
#                    name  origin  model_year   mpg horsepower
# 1     buick skylark 320       1          70  15.0        165
# 2    plymouth satellite       1          70  18.0        150
# 3         amc rebel sst       1          70  16.0        150
# 4           ford torino       1          70  17.0        140
# 5      ford galaxie 500       1          70  15.0        198
# ..                  ...     ...         ...   ...        ...
# 393     ford mustang gl       1          82  27.0         86
# 394           vw pickup       2          82  44.0         52
# 395       dodge rampage       1          82  32.0         84
# 396         ford ranger       1          82  28.0         79
# 397          chevy s-10       1          82  31.0         82
#
# [397 rows x 5 columns]

# %%
df.fillna(23.56)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# 5    15.0          8         429.0        198    4341          10.0
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                name
# 1            70       1   buick skylark 320
# 2            70       1  plymouth satellite
# 3            70       1       amc rebel sst
# 4            70       1         ford torino
# 5            70       1    ford galaxie 500
# ..          ...     ...                 ...
# 393          82       1     ford mustang gl
# 394          82       2           vw pickup
# 395          82       1       dodge rampage
# 396          82       1         ford ranger
# 397          82       1          chevy s-10
#
# [397 rows x 9 columns]

# %%
df[['name','origin','model_year','mpg']]
# Out:
#                    name  origin  model_year   mpg
# 1     buick skylark 320       1          70  15.0
# 2    plymouth satellite       1          70  18.0
# 3         amc rebel sst       1          70  16.0
# 4           ford torino       1          70  17.0
# 5      ford galaxie 500       1          70  15.0
# ..                  ...     ...         ...   ...
# 393     ford mustang gl       1          82  27.0
# 394           vw pickup       2          82  44.0
# 395       dodge rampage       1          82  32.0
# 396         ford ranger       1          82  28.0
# 397          chevy s-10       1          82  31.0
#
# [397 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397 entries, 1 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   model_year    397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 31.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df[['name','origin','model_year','mpg']]
# Out:
#                    name  origin  model_year   mpg
# 0                   NaN       1          70  18.0
# 1     buick skylark 320       1          70  15.0
# 2    plymouth satellite       1          70  18.0
# 3         amc rebel sst       1          70  16.0
# 4           ford torino       1          70  17.0
# ..                  ...     ...         ...   ...
# 393     ford mustang gl       1          82  27.0
# 394           vw pickup       2          82  44.0
# 395       dodge rampage       1          82  32.0
# 396         ford ranger       1          82  28.0
# 397          chevy s-10       1          82  31.0
#
# [398 rows x 4 columns]

# %%
df['name'].fillna('maruti')
# Out:
# 0                  maruti
# 1                  maruti
# 2      plymouth satellite
# 3           amc rebel sst
# 4             ford torino
#               ...
# 393       ford mustang gl
# 394             vw pickup
# 395         dodge rampage
# 396           ford ranger
# 397            chevy s-10
# Name: name, Length: 398, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          396 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
import pandas as pd
df =pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          396 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 396 entries, 2 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           396 non-null    float64
#  1   cylinders     396 non-null    int64
#  2   displacement  396 non-null    float64
#  3   horsepower    396 non-null    object
#  4   weight        396 non-null    int64
#  5   acceleration  396 non-null    float64
#  6   model_year    396 non-null    int64
#  7   origin        396 non-null    int64
#  8   name          396 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 30.9+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 396 entries, 2 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           396 non-null    float64
#  1   cylinders     396 non-null    int64
#  2   displacement  396 non-null    float64
#  3   horsepower    396 non-null    object
#  4   weight        396 non-null    int64
#  5   acceleration  396 non-null    float64
#  6   model_year    396 non-null    int64
#  7   origin        396 non-null    int64
#  8   name          396 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 30.9+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          396 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df[['name','origin','model_year','mpg']]
# Out:
#                    name  origin  model_year   mpg
# 0                   NaN       1          70  18.0
# 1                   NaN       1          70  15.0
# 2    plymouth satellite       1          70  18.0
# 3         amc rebel sst       1          70  16.0
# 4           ford torino       1          70  17.0
# ..                  ...     ...         ...   ...
# 393     ford mustang gl       1          82  27.0
# 394           vw pickup       2          82  44.0
# 395       dodge rampage       1          82  32.0
# 396         ford ranger       1          82  28.0
# 397          chevy s-10       1          82  31.0
#
# [398 rows x 4 columns]

# %%
df['name'].fillna('pppp')
# Out:
# 0                    pppp
# 1                    pppp
# 2      plymouth satellite
# 3           amc rebel sst
# 4             ford torino
#               ...
# 393       ford mustang gl
# 394             vw pickup
# 395         dodge rampage
# 396           ford ranger
# 397            chevy s-10
# Name: name, Length: 398, dtype: object

# %%
df_head= df.head(7)
df_head.set_index('name',inplace=True)
df_head
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
# ford galaxie 500           15.0          8         429.0        198    4341
# chevrolet impala           14.0          8         454.0        220    4354
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70       1
# buick skylark 320                  11.5          70       1
# plymouth satellite                 11.0          70       1
# amc rebel sst                      12.0          70       1
# ford torino                        10.5          70       1
# ford galaxie 500                   10.0          70       1
# chevrolet impala                    9.0          70       1

# %%
df.iloc[3,4]
# Out:
# 3433

# %%
df.iloc[0,-4]
# Out:
# 12.0

# %%
df.iloc[1:5,1:6]
# Out:
#    cylinders  displacement horsepower  weight  acceleration
# 1          8         350.0        165    3693          11.5
# 2          8         318.0        150    3436          11.0
# 3          8         304.0        150    3433          12.0
# 4          8         302.0        140    3449          10.5

# %%
df_head=df.head()
df_head.set_index('name',inplace=True)c
df_head.loc['buick skylark 320':'amc rebel sst']
# Out:
#                      mpg  cylinders  displacement horsepower  weight  \
# name
# buick skylark 320   15.0          8         350.0        165    3693
# plymouth satellite  18.0          8         318.0        150    3436
# amc rebel sst       16.0          8         304.0        150    3433
#
#                     acceleration  model_year  origin
# name
# buick skylark 320           11.5          70       1
# plymouth satellite          11.0          70       1
# amc rebel sst               12.0          70       1

# %%
#Subsetting from the full dataset
df.loc[0:5, ['cylinders', 'horsepower', 'name']]
# Out:
#    cylinders horsepower                       name
# 0          8        130  chevrolet chevelle malibu
# 1          8        165          buick skylark 320
# 2          8        150         plymouth satellite
# 3          8        150              amc rebel sst
# 4          8        140                ford torino
# 5          8        198           ford galaxie 500

# %%
df.loc[df['model_year'] == 72 ]
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 57  24.0          4         113.0         95    2278          15.5
# 58  25.0          4          97.5         80    2126          17.0
# 59  23.0          4          97.0         54    2254          23.5
# 60  20.0          4         140.0         90    2408          19.5
# 61  21.0          4         122.0         86    2226          16.5
# 62  13.0          8         350.0        165    4274          12.0
# 63  14.0          8         400.0        175    4385          12.0
# 64  15.0          8         318.0        150    4135          13.5
# 65  14.0          8         351.0        153    4129          13.0
# 66  17.0          8         304.0        150    3672          11.5
# 67  11.0          8         429.0        208    4633          11.0
# 68  13.0          8         350.0        155    4502          13.5
# 69  12.0          8         350.0        160    4456          13.5
# 70  13.0          8         400.0        190    4422          12.5
# 71  19.0          3          70.0         97    2330          13.5
# 72  15.0          8         304.0        150    3892          12.5
# 73  13.0          8         307.0        130    4098          14.0
# 74  13.0          8         302.0        140    4294          16.0
# 75  14.0          8         318.0        150    4077          14.0
# 76  18.0          4         121.0        112    2933          14.5
# 77  22.0          4         121.0         76    2511          18.0
# 78  21.0          4         120.0         87    2979          19.5
# 79  26.0          4          96.0         69    2189          18.0
# 80  22.0          4         122.0         86    2395          16.0
# 81  28.0          4          97.0         92    2288          17.0
# 82  23.0          4         120.0         97    2506          14.5
# 83  28.0          4          98.0         80    2164          15.0
# 71          72       3                   mazda rx2 coupe
# 72          72       1                  amc matador (sw)
# 73          72       1  chevrolet chevelle concours (sw)
# 74          72       1             ford gran torino (sw)
# 75          72       1    plymouth satellite custom (sw)
# 76          72       2                   volvo 145e (sw)
# 77          72       2               volkswagen 411 (sw)
# 78          72       2                  peugeot 504 (sw)
# 79          72       2                   renault 12 (sw)
# 80          72       1                   ford pinto (sw)
# 81          72       3                   datsun 510 (sw)
# 82          72       3       toyouta corona mark ii (sw)
# 83          72       1                   dodge colt (sw)
# 84          72       3          toyota corolla 1600 (sw)

# %%
[df['model_year'] == 72 ]
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  393    False
#  394    False
#  395    False
#  396    False
#  397    False
#  Name: model_year, Length: 398, dtype: bool]

# %%
df.loc[(df['origin']==2)&(df['cylinders']==5)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 274  20.3          5         131.0        103    2830          15.9
# 297  25.4          5         183.0         77    3530          20.1
# 327  36.4          5         121.0         67    2950          19.9
#
#      model_year  origin                 name
# 274          78       2            audi 5000
# 297          79       2   mercedes benz 300d
# 327          80       2  audi 5000s (diesel)

# %%
df['horsepower']=pd.to_numeric(df['horsepower'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
df.loc[(df['mpg']>29)&(df['horsepower']<93.5)&(df['weight']<2500)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 51   30.0          4          79.0        70.0    2074          19.5
# 52   30.0          4          88.0        76.0    2065          14.5
# 53   31.0          4          71.0        65.0    1773          19.0
# 54   35.0          4          72.0        69.0    1613          18.0
# 129  31.0          4          79.0        67.0    1950          19.0
# ..    ...        ...           ...         ...     ...           ...
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 391  36.0          4         135.0        84.0    2370          13.0
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
#
#      model_year  origin                 name
# 51           71       2          peugeot 304
# 52           71       2            fiat 124b
# 53           71       3  toyota corolla 1200
# 54           71       3          datsun 1200
# 129          74       3          datsun b210
# ..          ...     ...                  ...
# 384          82       3   honda civic (auto)
# 385          82       3        datsun 310 gx
# 391          82       1    dodge charger 2.2
# 394          82       2            vw pickup
# 395          82       1        dodge rampage
#
# [81 rows x 9 columns]

# %%
df.loc[(df['displacement']>262)&(df['horsepower']>126)&(df['weight']>=2800)&(df['weight']<=3600)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 121  15.0          8         318.0       150.0    3399          11.0
# 166  13.0          8         302.0       129.0    3169          12.0
# 251  20.2          8         302.0       139.0    3570          12.8
# 262  19.2          8         305.0       145.0    3425          13.2
# 264  18.1          8         302.0       139.0    3205          11.2
#
#      model_year  origin                          name
# 0            70       1     chevrolet chevelle malibu
# 2            70       1            plymouth satellite
# 3            70       1                 amc rebel sst
# 4            70       1                   ford torino
# 10           70       1           dodge challenger se
# 13           70       1       buick estate wagon (sw)
# 121          73       1             dodge dart custom
# 166          75       1               ford mustang ii
# 251          78       1          mercury monarch ghia
# 262          78       1  chevrolet monte carlo landau
# 264          78       1                   ford futura

# %%
marks=[{'chemistry':67,'physics':45,'mathematics':50,'english':19},
      {'chemistry':90,'physics':92,'mathematics':87,'english':90},
      {'chemistry':66,'physics':72,'mathematics':81,'english':72},
      {'chemistry':32,'physics':40,'mathematics':12,'english':68}]
marks_df=pd.DataFrame(marks,index=['subodh','ram','abdul','john'])
marks_df
# Out:
#         chemistry  physics  mathematics  english
# subodh         67       45           50       19
# ram            90       92           87       90
# abdul          66       72           81       72
# john           32       40           12       68

# %%
f=marks_df<33
marks_df.mask(f,'fail')
# Out:
#        chemistry  physics mathematics english
# subodh        67       45          50    fail
# ram           90       92          87      90
# abdul         66       72          81      72
# john        fail       40        fail      68

# %%
df.sort_values(by = 'cylinders')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 111  18.0          3          70.0        90.0    2124          13.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 243  21.5          3          80.0       110.0    2720          13.5
# 267  27.5          4         134.0        95.0    2560          14.2
# ..    ...        ...           ...         ...     ...           ...
# 86   14.0          8         304.0       150.0    3672          11.5
# 285  17.0          8         305.0       130.0    3840          15.4
# 286  17.6          8         302.0       129.0    3725          13.4
# 92   13.0          8         351.0       158.0    4363          13.0
# 0    18.0          8         307.0       130.0    3504          12.0
#
#      model_year  origin                       name
# 111          73       3                  maxda rx3
# 71           72       3            mazda rx2 coupe
# 334          80       3              mazda rx-7 gs
# 243          77       3                 mazda rx-4
# 267          78       3              toyota corona
# ..          ...     ...                        ...
# 86           73       1                amc matador
# 285          79       1  chevrolet caprice classic
# 286          79       1            ford ltd landau
# 92           73       1                   ford ltd
# 0            70       1  chevrolet chevelle malibu
#
# [398 rows x 9 columns]

# %%
df.sort_values(['acceleration', 'weight'], ascending = (0,1))
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 299  27.2          4         141.0        71.0    3190          24.8
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
# 59   23.0          4          97.0        54.0    2254          23.5
# 195  29.0          4          85.0        52.0    2035          22.2
# ..    ...        ...           ...         ...     ...           ...
# 116  16.0          8         400.0       230.0    4278           9.5
# 6    14.0          8         454.0       220.0    4354           9.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 7    14.0          8         440.0       215.0    4312           8.5
# 11   14.0          8         340.0       160.0    3609           8.0
#
#      model_year  origin                name
# 299          79       2         peugeot 504
# 394          82       2           vw pickup
# 326          80       2  vw dasher (diesel)
# 59           72       2   volkswagen type 3
# 195          76       1  chevrolet chevette
# ..          ...     ...                 ...
# 116          73       1  pontiac grand prix
# 6            70       1    chevrolet impala
# 9            70       1  amc ambassador dpl
# 7            70       1   plymouth fury iii
# 11           70       1  plymouth 'cuda 340
#
# [398 rows x 9 columns]

# %%
import pandas as pd
marks={'chemistry':[67,90,66,32],
      'physics':[45,92,72,40],
      'methematics':[50,87,81,12],
      'english':[19,90,72,68]}
marks_df=pd.DataFrame(marks,index=['subodh','ram','abdul','john'])
marks_df
# Out:
#         chemistry  physics  methematics  english
# subodh         67       45           50       19
# ram            90       92           87       90
# abdul          66       72           81       72
# john           32       40           12       68

# %%
#encrypting marks as sine of marks
import numpy as np
encrypted_marks = np.sin(marks_df)
encrypted_marks
# Out:
#         chemistry   physics  methematics   english
# subodh  -0.855520  0.850904    -0.262375  0.149877
# ram      0.893997 -0.779466    -0.821818  0.893997
# abdul   -0.026551  0.253823    -0.629888  0.253823
# john     0.551427  0.745113    -0.536573 -0.897928

# %%
encrypted_marks.reset_index(inplace = True)
encrypted_marks
# Out:
#     index  chemistry   physics  methematics   english
# 0  subodh  -0.855520  0.850904    -0.262375  0.149877
# 1     ram   0.893997 -0.779466    -0.821818  0.893997
# 2   abdul  -0.026551  0.253823    -0.629888  0.253823
# 3    john   0.551427  0.745113    -0.536573 -0.897928

# %%
marks_df=marks_df+5
marks_df
# Out:
#         chemistry  physics  methematics  english
# subodh         82       60           65       34
# ram           105      107          102      105
# abdul          81       87           96       87
# john           47       55           27       83

# %%
marks_df=marks_df+[5,10,10,2]
marks_df
# Out:
#         chemistry  physics  methematics  english
# subodh         87       70           75       36
# ram           110      117          112      107
# abdul          86       97          106       89
# john           52       65           37       85

# %%
#Creating the DataFrame
marks = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
        'Mathematics': [50,87,81,12],  
        'English': [19,90,72,68]}
marks_df = pd.DataFrame(marks, index = ['James', 'Lee', 'Anderson', 'John'])

# %%
marks_df.apply(np.sum,axis=0)
# Out:
# Chemistry      255
# Physics        249
# Mathematics    230
# English        249
# dtype: int64

# %%
marks_df.apply(np.sum, axis = 1)
# Out:
# James       181
# Lee         359
# Anderson    291
# John        152
# dtype: int64

# %%
marks_df.apply(func = np.mean, axis = 0 )
# Out:
# Chemistry      63.75
# Physics        62.25
# Mathematics    57.50
# English        62.25
# dtype: float64

# %%
marks_df.apply(func = np.mean, axis = 0, result_type = 'broadcast')
# Out:
#           Chemistry  Physics  Mathematics  English
# James            63       62           57       62
# Lee              63       62           57       62
# Anderson         63       62           57       62
# John             63       62           57       62

# %%
df.agg([min,max])
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# min   9.0          3          68.0        100    1613           8.0
# max  46.6          8         455.0          ?    5140          24.8
#
#      model_year  origin                     name
# min          70       1  amc ambassador brougham
# max          82       3         vw rabbit custom

# %%
df.groupby(['model_year']).count()[['name']]
# Out:
#             name
# model_year
# 70            29
# 71            28
# 72            28
# 73            40
# 74            27
# 75            30
# 76            34
# 77            28
# 78            36
# 79            29
# 80            29
# 81            29
# 82            31

# %%
df.agg(func=sum,axis=0)
# Out:
# mpg                                                        9358.8
# cylinders                                                    2171
# displacement                                              76983.5
# horsepower      1301651501501401982202152251901701601502259595...
# weight                                                    1182229
# acceleration                                               6196.1
# model_year                                                  30252
# origin                                                        626
# name            chevrolet chevelle malibubuick skylark 320plym...
# dtype: object

# %%
df_num_col=df[['mpg','cylinders','displacement','weight','acceleration','model_year','origin']]
df_num_col.agg([min,max])
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model_year  origin
# min   9.0          3          68.0    1613           8.0          70       1
# max  46.6          8         455.0    5140          24.8          82       3

# %%
df.groupby(by='model_year').count()[['name']]
# Out:
#             name
# model_year
# 70            29
# 71            28
# 72            28
# 73            40
# 74            27
# 75            30
# 76            34
# 77            28
# 78            36
# 79            29
# 80            29
# 81            29
# 82            31

# %%
df.groupby(by='horsepower').count()[['model_year','cylinders']]
# Out:
#             model_year  cylinders
# horsepower
# 100                 17         17
# 102                  1          1
# 103                  1          1
# 105                 12         12
# 107                  1          1
# ...                ...        ...
# 95                  14         14
# 96                   3          3
# 97                   9          9
# 98                   2          2
# ?                    6          6
#
# [94 rows x 2 columns]

# %%
df.groupby(['cylinders','model_year']).agg({'horsepower':['mean','min','max']})
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1791, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1790 try:
# -> 1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    1794         how,
#    1795         axis=data.ndim - 1,
#    1796         min_count=min_count,
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# -> 1039 return cy_op.cython_operation(
#    1040     values=values,
#    1041     axis=axis,
#    1042     min_count=min_count,
#    1043     comp_ids=ids,
#    1044     ngroups=ngroups,
#    1045     **kwargs,
#    1046 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:708, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     700     return self._ea_wrap_cython_operation(
#     701         values,
#     702         min_count=min_count,
#    (...)
#     705         **kwargs,
#     706     )
# --> 708 return self._cython_op_ndim_compat(
#     709     values,
#     710     min_count=min_count,
#     711     ngroups=ngroups,
#     712     comp_ids=comp_ids,
#     713     mask=None,
#     714     **kwargs,
#     715 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:512, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     511     result_mask = result_mask[None, :]
# --> 512 res = self._call_cython_op(
#     513     values2d,
#     514     min_count=min_count,
#     515     ngroups=ngroups,
#     516     comp_ids=comp_ids,
#     517     mask=mask,
#     518     result_mask=result_mask,
#     519     **kwargs,
#     520 )
#     521 if res.shape[0] == 1:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:571, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     570 out_shape = self._get_output_shape(ngroups, values)
# --> 571 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     572 values = self._get_cython_vals(values)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:192, in WrappedCythonOp._get_cython_function(cls, kind, how, dtype, is_numeric)
#     190 elif "object" not in f.__signatures__:
#     191     # raise NotImplementedError here rather than TypeError later
# --> 192     raise NotImplementedError(
#     193         f"function is not implemented for this dtype: "
#     194         f"[how->{how},dtype->{dtype_str}]"
#     195     )
#     196 return f
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '889095?728690707665696070'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\nanops.py:1634, in _ensure_numeric(x)
#    1633 try:
# -> 1634     x = complex(x)
#    1635 except ValueError as err:
#    1636     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.groupby(['cylinders','model_year']).agg({'horsepower':['mean','min','max']})
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:895, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     892 func = maybe_mangle_lambdas(func)
#     894 op = GroupByApply(self, func, args, kwargs)
# --> 895 result = op.agg()
#     896 if not is_dict_like(func) and result is not None:
#     897     return result
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\apply.py:172, in Apply.agg(self)
#     169     return self.apply_str()
#     171 if is_dict_like(arg):
# --> 172     return self.agg_dict_like()
#     173 elif is_list_like(arg):
#     174     # we require a list, but not a 'str'
#     175     return self.agg_list_like()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\apply.py:504, in Apply.agg_dict_like(self)
#     501     results = {key: colg.agg(how) for key, how in arg.items()}
#     502 else:
#     503     # key used for column selection and output
# --> 504     results = {
#     505         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506     }
#     508 # set the final keys
#     509 keys = list(arg.keys())
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\apply.py:505, in <dictcomp>(.0)
#     501     results = {key: colg.agg(how) for key, how in arg.items()}
#     502 else:
#     503     # key used for column selection and output
#     504     results = {
# --> 505         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506     }
#     508 # set the final keys
#     509 keys = list(arg.keys())
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:281, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     277 elif isinstance(func, abc.Iterable):
#     278     # Catch instances of lists / tuples
#     279     # but not the class list / tuple itself.
#     280     func = maybe_mangle_lambdas(func)
# --> 281     ret = self._aggregate_multiple_funcs(func)
#     282     if relabeling:
#     283         # columns is not narrowed by mypy from relabeling flag
#     284         assert columns is not None  # for mypy
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:336, in SeriesGroupBy._aggregate_multiple_funcs(self, arg)
#     333 for idx, (name, func) in enumerate(arg):
#     335     key = base.OutputKey(label=name, position=idx)
# --> 336     results[key] = self.aggregate(func)
#     338 if any(isinstance(x, DataFrame) for x in results.values()):
#     339     from pandas import concat
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:275, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     272     kwargs = {}
#     274 if isinstance(func, str):
# --> 275     return getattr(self, func)(*args, **kwargs)
#     277 elif isinstance(func, abc.Iterable):
#     278     # Catch instances of lists / tuples
#     279     # but not the class list / tuple itself.
#     280     func = maybe_mangle_lambdas(func)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2183, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2181     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2182 else:
# -> 2183     result = self._cython_agg_general(
#    2184         "mean",
#    2185         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2186         numeric_only=numeric_only,
#    2187     )
#    2188     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1810, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, ignore_failures, **kwargs)
#    1806     return result
#    1808 # TypeError -> we may have an exception in trying to aggregate
#    1809 #  continue and exclude the block
# -> 1810 new_mgr = data.grouped_reduce(array_func, ignore_failures=ignore_failures)
#    1812 if not is_ser and len(new_mgr) < orig_len:
#    1813     warn_dropping_nuisance_columns_deprecated(type(self), how, numeric_only)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:199, in SingleDataManager.grouped_reduce(self, func, ignore_failures)
#     193 """
#     194 ignore_failures : bool, default False
#     195     Not used; for compatibility with ArrayManager/BlockManager.
#     196 """
#     198 arr = self.array
# --> 199 res = func(arr)
#     200 index = default_index(len(res))
#     202 mgr = type(self).from_array(res, index)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1804, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    (...)
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
# -> 1804     result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1806 return result
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1745, in GroupBy._agg_py_fallback(self, values, ndim, alt)
#    1740     ser = df.iloc[:, 0]
#    1742 # We do not get here with UDFs, so we know that our dtype
#    1743 #  should always be preserved by the implemented aggregations
#    1744 # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1745 res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1747 if isinstance(values, Categorical):
#    1748     # Because we only get here with known dtype-preserving
#    1749     #  reductions, we cast back to Categorical.
#    1750     # TODO: if we ever get "rank" working, exclude it here.
#    1751     res_values = type(values)._from_sequence(res_values, dtype=values.dtype)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:1081, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#    1078     preserve_dtype = True
#    1080 else:
# -> 1081     result = self._aggregate_series_pure_python(obj, func)
#    1083 npvalues = lib.maybe_convert_objects(result, try_float=False)
#    1084 if preserve_dtype:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:1104, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1101 splitter = get_splitter(obj, ids, ngroups, axis=0)
#    1103 for i, group in enumerate(splitter):
# -> 1104     res = func(group)
#    1105     res = libreduction.extract_result(res)
#    1107     if not initialized:
#    1108         # We only do this validation on the first iteration
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2185, in GroupBy.mean.<locals>.<lambda>(x)
#    2181     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2182 else:
#    2183     result = self._cython_agg_general(
#    2184         "mean",
# -> 2185         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2186         numeric_only=numeric_only,
#    2187     )
#    2188     return result.__finalize__(self.obj, method="groupby")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
#   11402         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   11403     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\nanops.py:418, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     415 if datetimelike and mask is None:
#     416     mask = isna(values)
# --> 418 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     420 if datetimelike:
#     421     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\nanops.py:706, in nanmean(values, axis, skipna, mask)
#     703     dtype_count = dtype
#     705 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 706 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     708 if axis is not None and getattr(the_sum, "ndim", False):
#     709     count = cast(np.ndarray, count)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\nanops.py:1637, in _ensure_numeric(x)
#    1634             x = complex(x)
#    1635         except ValueError as err:
#    1636             # e.g. "foo"
# -> 1637             raise TypeError(f"Could not convert {x} to numeric") from err
#    1638 return x
#
# TypeError: Could not convert 889095?728690707665696070 to numeric

# %%
df.groupby(by='model_year').mean().sort_values('acceleration')[['acceleration']]
# Out:
# C:\Users\bldea0\AppData\Local\Temp\ipykernel_10620\202178759.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.group
# 40 2019-11-17  Central  Hermann       Luis  Home Theater   11.00     500.000
# 41 2019-12-04  Central  Hermann       Luis  Home Theater   94.00     500.000
# 42 2019-12-21  Central   Martha     Steven  Home Theater   28.00     500.000
# 43        NaT      NaN      NaN        NaN           NaN  278.00    1125.000
# 44        NaT      NaN      NaN        NaN           NaN   34.75     140.625
#
#      Sale_amt
# 0   113810.00
# 1    25000.00
# 2    43128.00
# 3     6075.00
# 4    67088.00
# 5    30000.00
# 6    89850.00
# 7   107820.00
# 8    38336.00
# 9    30000.00
# 10  107820.00
# 11   14500.00
# 12   40500.00
# 13   41930.00
# 14     250.00
# 15     936.00
# 16   14000.00
# 17   14400.00
# 18    3375.00
# 19    5616.00
# 20   80266.00
# 21    4329.00
# 22   23000.00
# 23   43500.00
# 24    2000.00
# 25    3500.00
# 26    2925.00
# 27   79068.00
# 28   21600.00
# 29   63494.00
# 30   40000.00
# 31     625.00
# 32    3627.00
# 33    3217.50
# 34    2457.00
# 35     375.00
# 36    8386.00
# 37   17100.00
# 38   28500.00
# 39   16772.00
# 40    5500.00
# 41   47000.00
# 42   14000.00
# 43   62550.00
# 44    7818.75

# %%
df.groupby('SalesMan').sum()[['Sale_amt']]
# Out:
# C:\Users\bldea0\AppData\Local\Temp\ipykernel_10460\4143099978.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('SalesMan').sum()[['Sale_amt']]
#            Sale_amt
# SalesMan
# Alexander  236703.0
# David      140955.0
# Diana       36100.0
# John       124016.0
# Karen       48204.0
# Luis       206373.0
# Michael     66836.0
# Shelli      33698.0
# Sigal      125037.5
# Stephen     88063.0
# Steven     199690.0

# %%
df.groupby(['Manager','SalesMan']).sum()[['Sale_amt']]
# Out:
# C:\Users\bldea0\AppData\Local\Temp\ipykernel_10460\970159690.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Manager','SalesMan']).sum()[['Sale_amt']]
#                    Sale_amt
# Manager SalesMan
# Douglas John       124016.0
#         Karen       48204.0
#         Michael     66836.0
# Hermann Luis       206373.0
#         Shelli      33698.0
#         Sigal      125037.5
# Martha  Alexander  236703.0
#         Diana       36100.0
#         Steven     199690.0
# Timothy David      140955.0
#         Stephen     88063.0

# %%
df.groupby(['SalesMan','Item']).sum()[['Units']]
# Out:
# C:\Users\bldea0\AppData\Local\Temp\ipykernel_10460\3504896505.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['SalesMan','Item']).sum()[['Units']]
#                         Units
# SalesMan  Item
# Alexander Cell Phone     64.0
#           Home Theater  124.0
#           Television    130.0
#           Video Games    78.0
# David     Cell Phone     27.0
#           Home Theater  126.0
#           Television     60.0
# Diana     Cell Phone     96.0
#           Home Theater   29.0
# John      Desk            2.0
#           Home Theater   87.0
#           Television     67.0
# Karen     Cell Phone     15.0
#           Home Theater   81.0
#           Video Games    74.0
# Luis      Home Theater  105.0
#           Television    126.0
#           Video Games    50.0
# Michael   Home Theater   57.0
#           Television     32.0
# Shelli    Desk            5.0
#           Home Theater   50.0
#           Video Games   138.0
# Sigal     Home Theater   28.0
#           Television     90.0
#           Video Games    55.0
# Stephen   Cell Phone     76.0
#           Desk            3.0
#           Home Theater    7.0
#           Television     56.0
# Steven    Home Theater   28.0
#           Television    155.0

# %%
df.groupby(['SalesMan','Item']).agg({'Units':sum,'Sale_amt':sum})
# Out:
#                         Units  Sale_amt
# SalesMan  Item
# Alexander Cell Phone     64.0   14400.0
#           Home Theater  124.0   62000.0
#           Television    130.0  155740.0
#           Video Games    78.0    4563.0
# David     Cell Phone     27.0    6075.0
#           Home Theater  126.0   63000.0
#           Television     60.0   71880.0
# Diana     Cell Phone     96.0   21600.0
#           Home Theater   29.0   14500.0
# John      Desk            2.0     250.0
#           Home Theater   87.0   43500.0
#           Television     67.0   80266.0
# Karen     Cell Phone     15.0    3375.0
#           Home Theater   81.0   40500.0
#           Video Games    74.0    4329.0
# Luis      Home Theater  105.0   52500.0
#           Television    126.0  150948.0
#           Video Games    50.0    2925.0
# Michael   Home Theater   57.0   28500.0
#           Television     32.0   38336.0
# Shelli    Desk            5.0     625.0
#           Home Theater   50.0   25000.0
#           Video Games   138.0    8073.0
# Sigal     Home Theater   28.0   14000.0
#           Television     90.0  107820.0
#           Video Games    55.0    3217.5
# Stephen   Cell Phone     76.0   17100.0
#           Desk            3.0     375.0
#           Home Theater    7.0    3500.0
#           Television     56.0   67088.0
# Steven    Home Theater   28.0   14000.0
#           Television    155.0  185690.0

# %%
df.groupby('Region').sum()[['SalesMan']]
# Out:
# C:\Users\bldea0\AppData\Local\Temp\ipykernel_10460\249404901.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Region').sum()[['Sale_amt']]
#          Sale_amt
# Region
# Central  829769.5
# East     321007.0
# West     154899.0

# %%
import numpy as np
df.pivot_table(df,index='SalesMan')
# Out:
# C:\Users\bldea0\AppData\Local\Temp\ipykernel_10460\2580803588.py:2: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df.pivot_table(df,index='SalesMan')
#                Sale_amt   Unit_price      Units
# SalesMan
# Alexander  29587.875000   529.750000  49.500000
# David      28191.000000   724.200000  42.600000
# Diana      18050.000000   362.500000  62.500000
# John       41338.666667   607.666667  52.000000
# Karen      16068.000000   261.166667  56.666667
# Luis       41274.600000   690.900000  56.200000
# Michael    33418.000000   849.000000  44.500000
# Shelli      8424.500000   185.500000  48.250000
# Sigal      41679.166667   585.500000  57.666667
# Stephen    22015.750000   512.000000  35.500000
# Steven     49922.500000  1023.500000  45.750000

# %%
pd.pivot_table(df[['Sale_amt','SalesMan']],index='SalesMan')
# Out:
#                Sale_amt
# SalesMan
# Alexander  29587.875000
# David      28191.000000
# Diana      18050.000000
# John       41338.666667
# Karen      16068.000000
# Luis       41274.600000
# Michael    33418.000000
# Shelli      8424.500000
# Sigal      41679.166667
# Stephen    22015.750000
# Steven     49922.500000

# %%
pd.pivot_table(df,index='SalesMan',columns='Item',values='Sale_amt')
# Out:
# Item       Cell Phone   Desk  Home Theater     Television  Video Games
# SalesMan
# Alexander     14400.0    NaN  20666.666667   77870.000000       2281.5
# David          6075.0    NaN  31500.000000   35940.000000          NaN
# Diana         21600.0    NaN  14500.000000            NaN          NaN
# John              NaN  250.0  43500.000000   80266.000000          NaN
# Karen          3375.0    NaN  40500.000000            NaN       4329.0
# Luis              NaN    NaN  26250.000000   75474.000000       2925.0
# Michael           NaN    NaN  28500.000000   38336.000000          NaN
# Shelli            NaN  625.0  25000.000000            NaN       4036.5
# Sigal             NaN    NaN  14000.000000  107820.000000       3217.5
# Stephen       17100.0  375.0   3500.000000   67088.000000          NaN
# Steven            NaN    NaN  14000.000000   61896.666667          NaN

# %%
import pandas as pd
from pandas import DataFrame
df = DataFrame(
                [
                    ['aryan','Singh','Full-time','administration',2,20000],
                    ['Rohan','Agarwal','intern','Technical',3,5000],
                    ['Riya','shaha','Full-time','administration',5,10000],
                    ['yash','bhatia','part-time','Technical',6,20000],
                    ['siddhant','khanna','full-time','Management',7,10000],
                ],columns=['First Name','Last Name','Type','Department','YoE','salary']  
              )               
df
# Out:
#   First Name Last Name       Type      Department  YoE  salary
# 0      aryan     Singh  Full-time  administration    2   20000
# 1      Rohan   Agarwal     intern       Technical    3    5000
# 2       Riya     shaha  Full-time  administration    5   10000
# 3       yash    bhatia  part-time       Technical    6   20000
# 4   siddhant    khanna  full-time      Management    7   10000

# %%
pd.pivot_table(df,index='Type')
# Out:
# C:\Users\bldea0\AppData\Local\Temp\ipykernel_10460\3965019829.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df,index='Type')
#            YoE  salary
# Type
# Full-time  3.5   15000
# full-time  7.0   10000
# intern     3.0    5000
# part-time  6.0   20000

# %%
pd.pivot_table(df[['salary','Type']],index='Type')
# Out:
#            salary
# Type
# Full-time   15000
# full-time   10000
# intern       5000
# part-time   20000

# %%
pd.pivot_table(df,index='Type',columns='Department',values='salary')
# Out:
# Department  Management  Technical  administration
# Type
# Full-time          NaN        NaN         15000.0
# full-time      10000.0        NaN             NaN
# intern             NaN     5000.0             NaN
# part-time          NaN    20000.0             NaN

# %%
import pandas as pd
marks_A = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
          }
marks_A_df = pd.DataFrame(marks_A, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_B = {'Chemistry': [72,45,60,98], 
        'Physics': [78,34,72,95],  
          }
marks_B_df = pd.DataFrame(marks_B, index = ['Nandini', 'Zoya', 'Shivam', 'James'])

# %%
pd.concat([marks_A_df,marks_B_df], sort = False)
# Out:
#          Chemistry  Physics
# Subodh          67       45
# Ram             90       92
# Abdul           66       72
# John            32       40
# Nandini         72       78
# Zoya            45       34
# Shivam          60       72
# James           98       95

# %%
pd.crosstab(df['model_year'], df['cylinders'])
# Out:
# cylinders   3   4  5   6   8
# model_year
# 70          0   7  0   4  18
# 71          0  13  0   8   7
# 72          1  14  0   0  13
# 73          1  11  0   8  20
# 74          0  15  0   7   5
# 75          0  12  0  12   6
# 76          0  15  0  10   9
# 77          1  14  0   5   8
# 78          0  17  1  12   6
# 79          0  12  1   6  10
# 80          1  25  1   2   0
# 81          0  21  0   7   1
# 82          0  28  0   3   0

# %%
#1
import pandas as pd
df=pd.read_csv('dataset/rainfall.csv')
df
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
#        MAY    JUN     JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0    358.5  295.5   285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1    374.4  457.2   421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2    343.6  503.3   465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3    306.4  447.0   660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4    323.0  738.3   990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
# ..     ...    ...     ...    ...    ...    ...    ...    ...     ...      ...
# 636  232.6  651.6   788.9  527.3  308.4  343.2  172.9   48.1  3302.5     35.5
# 637  217.6  999.6  1108.5  636.3  263.1  234.9   84.6   18.4  3621.6      3.3
# 638  294.7  556.9   539.9  352.7  266.2  359.4  213.5   51.3  2958.4     65.0
# 639  174.6  698.1  1110.4  592.9  230.7  213.1   93.6   25.8  3253.1     13.1
# 640  171.7  330.2   287.7  217.5  163.1  157.1  117.7   58.8  1600.0     35.5
#
#      Mar-May  Jun-Sep  Oct-Dec
# 0      540.7   1207.2    892.1
# 1      483.5   1757.2    705.3
# 2      405.6   1884.4    574.7
# 3      841.3   1848.5    231.0
# 4      645.4   3008.4    268.1
# ..       ...      ...      ...
# 636    426.6   2276.2    564.2
# 637    272.9   3007.5    337.9
# 638    553.5   1715.7    624.2
# 639    275.4   2632.1    332.5
# 640    232.4    998.5    333.6
#
# [641 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_UT_NAME  641 non-null    object
#  1   DISTRICT       641 non-null    object
#  2   JAN            641 non-null    float64
#  3   FEB            641 non-null    float64
#  4   MAR            641 non-null    float64
#  5   APR            641 non-null    float64
#  6   MAY            641 non-null    float64
#  7   JUN            641 non-null    float64
#  8   JUL            641 non-null    float64
#  9   AUG            641 non-null    float64
#  10  SEP            641 non-null    float64
#  11  OCT            641 non-null    float64
#  12  NOV            641 non-null    float64
#  13  DEC            641 non-null    float64
#  14  ANNUAL         641 non-null    float64
#  15  Jan-Feb        641 non-null    float64
#  16  Mar-May        641 non-null    float64
#  17  Jun-Sep        641 non-null    float64
#  18  Oct-Dec        641 non-null    float64
# dtypes: float64(17), object(2)
# memory usage: 95.3+ KB

# %%
#3
pd.pivot_table(df,index='DISTRICT',values='ANNUAL')
# Out:
#              ANNUAL
# DISTRICT
# ADILABAD     1120.0
# AGRA          774.6
# AHMEDABAD     639.9
# AHMEDNAGAR    573.2
# AIZAWL       2814.4
# ...             ...
# YADGIR        834.5
# YAMUNANAGAR  1107.0
# YANAM        1336.5
# YAVATMAL      982.8
# ZUNHEBOTO    2080.0
#
# [637 rows x 1 columns]

# %%
#3
df.groupby('DISTRICT').max().sort_values('ANNUAL',ascending=0)[['ANNUAL']]
# Out:
#                ANNUAL
# DISTRICT
# TAMENGLONG     7229.3
# JAINTIA HILLS  6379.9
# EAST KHASI HI  6166.1
# UPPER SIANG    4402.1
# UDUPI          4306.0
# ...               ...
# BARMER          268.6
# SRI GANGANAGA   252.9
# KARGIL          223.3
# JAISALMER       181.2
# LADAKH (LEH)     94.6
#
# [637 rows x 1 columns]

# %%
#4
df.groupby('STATE_UT_NAME').sum().sort_values('ANNUAL',ascending=0)[['ANNUAL']].head(5)
# Out:
# C:\Users\bldea0\AppData\Local\Temp\ipykernel_5928\574471694.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('STATE_UT_NAME').sum().sort_values('ANNUAL',ascending=0)[['ANNUAL']].head(5)
#                     ANNUAL
# STATE_UT_NAME
# UTTAR PRADESH      67836.6
# ASSAM              66267.7
# MADHYA PRADESH     51615.5
# ARUNACHAL PRADESH  46838.0
# BIHAR              45621.1

# %%
#5
df.drop(columns=['Jan-Feb','Mar-May','Jun-Sep','Oct-Dec'],inplace=True)

# %%
df
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
#        MAY    JUN     JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL
# 0    358.5  295.5   285.0  271.9  354.8  326.0  315.2  250.9  2805.2
# 1    374.4  457.2   421.3  423.1  455.6  301.2  275.8  128.3  3015.7
# 2    343.6  503.3   465.4  460.9  454.8  276.1  198.6  100.0  2913.3
# 3    306.4  447.0   660.1  427.8  313.6  167.1   34.1   29.8  3043.8
# 4    323.0  738.3   990.9  711.2  568.0  206.9   29.5   31.7  4034.7
# ..     ...    ...     ...    ...    ...    ...    ...    ...     ...
# 636  232.6  651.6   788.9  527.3  308.4  343.2  172.9   48.1  3302.5
# 637  217.6  999.6  1108.5  636.3  263.1  234.9   84.6   18.4  3621.6
# 638  294.7  556.9   539.9  352.7  266.2  359.4  213.5   51.3  2958.4
# 639  174.6  698.1  1110.4  592.9  230.7  213.1   93.6   25.8  3253.1
# 640  171.7  330.2   287.7  217.5  163.1  157.1  117.7   58.8  1600.0
#
# [641 rows x 15 columns]

# %%
#6
import numpy as np
pd.pivot_table(df,index='STATE_UT_NAME')
# Out:
# C:\Users\bldea0\AppData\Local\Temp\ipykernel_5928\1025186281.py:2: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df,index='STATE_UT_NAME')
#                                   ANNUAL         APR         AUG         DEC  \
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS  2911.400000   86.966667  385.300000  159.733333
# ANDHRA PRADESH                945.073913   19.873913  179.426087   15.565217
# ARUNACHAL PRADESH            2927.375000  275.162500  378.600000   35.956250
# ASSAM                        2454.359259  181.266667  377.370370   11.440741
# BIHAR                        1200.555263   16.865789  289.481579    5.786842
# CHANDIGARH                   1070.600000   14.800000  287.500000   23.400000
# CHATISGARH                   1286.350000   13.116667  375.338889    5.811111
# DADAR NAGAR HAVELI           2374.100000    0.000000  655.900000    0.000000
# DAMAN AND DUI                1535.700000    0.100000  394.600000    0.450000
# DELHI                         747.100000    8.900000  245.500000    8.600000
# GOA                          3278.500000    7.800000  683.800000   10.200000
# GUJARAT                       924.342308    0.507692  257.630769    1.592308
# HARYANA                       614.557143    7.619048  190.909524    7.914286
# HIMACHAL                     1371.591667   47.683333  322.325000   38.225000
# JAMMU AND KASHMIR            1016.618182   82.268182  167.918182   46.395455
# JHARKHAND                    1303.437500   18.662500  310.316667    6.704167
# KARNATAKA                    1194.616667   36.773333  209.256667   11.170000
# KERALA                       2937.392857  109.021429  417.950000   38.242857
# LAKSHADWEEP                  1600.000000   48.900000  217.500000   58.800000
# MADHYA PRADESH               1032.310000    3.270000  331.048000    8.790000
# MAHARASHTRA                  1278.588571    6.974286  314.585714    7.417143
# MANIPUR                      2496.633333  150.766667  451.800000   11.788889
# MEGHALAYA                    3682.842857  211.228571  584.371429   11.042857
# MIZORAM                      2616.322222  152.600000  440.588889   15.288889
# NAGALAND                     1940.700000  134.227273  350.872727   10.354545
# ORISSA                       1466.120000   36.653333  363.346667    5.136667
# PONDICHERRY                  1378.475000   12.275000  116.425000  227.350000
# PUNJAB                        648.545000   12.160000  172.415000   13.905000
# RAJASTHAN                     581.596970    3.303030  194.554545    3.021212
# SIKKIM                       2838.350000  206.900000  434.600000   20.900000
# TAMIL NADU                    960.006250   42.596875   91.571875   96.487500
#8
df.groupby('STATE_UT_NAME').max()[['DISTRICT','MAY']]
# Out:
#                                    DISTRICT    MAY
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN  374.4
# ANDHRA PRADESH                WEST GODAVARI   96.6
# ARUNACHAL PRADESH                WEST SIANG  453.0
# ASSAM                         UDALGURI(DARA  604.0
# BIHAR                        WEST CHAMPARAN  155.7
# CHANDIGARH                       CHANDIGARH   30.1
# CHATISGARH                          SURGUJA   38.6
# DADAR NAGAR HAVELI                      DNH    7.4
# DAMAN AND DUI                           DIU    7.4
# DELHI                            WEST DELHI   19.3
# GOA                               SOUTH GOA   94.3
# GUJARAT                              VALSAD   12.5
# HARYANA                         YAMUNANAGAR   27.9
# HIMACHAL                                UNA   91.7
# JAMMU AND KASHMIR                  UDHAMPUR  111.4
# JHARKHAND                    WEST SINGHBHUM   86.1
# KARNATAKA                            YADGIR  193.8
# KERALA                              WAYANAD  300.4
# LAKSHADWEEP                     LAKSHADWEEP  171.7
# MADHYA PRADESH                      VIDISHA   19.9
# MAHARASHTRA                        YAVATMAL   60.2
# MANIPUR                              UKHRUL  539.9
# MEGHALAYA                     WEST GARO HIL  733.7
# MIZORAM                            SERCHHIP  351.4
# NAGALAND                          ZUNHEBOTO  325.6
# ORISSA                           SUNDARGARH  136.8
# PONDICHERRY                           YANAM   43.6
# PUNJAB                           TARN TARAN   25.6
# RAJASTHAN                           UDAIPUR   20.7
# SIKKIM                          WEST SIKKIM  355.4
# TAMIL NADU                     VIRUDHUNAGAR  141.5
# TRIPURA                        WEST TRIPURA  440.1
# UTTAR PRADESH                      VARANASI   38.6
# UTTARANCHAL                      UTTARKASHI  102.1
# WEST BENGAL                   WEST MIDNAPOR  345.4

# %%
import matplotlib.pyplot as plt

# %%
#importing the required packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#creating two arrays
X=np.array([1,2,3,4,5])
Y=X**2

# %%
#plotting the values
plt.plot(X,Y)

# %%
x=np.arange(1,16)
y=x**2
z=(y/2)+40

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes as [left, bottom, width, height]
ax = fig.add_axes([0,0,1,1])

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.plot(x,y,color="g",label='line1' )

# %%
df.plot(x='model_year',y='acceleration',marker='o',kind='scatter');

# %%
df.groupby('model_year').mean()[['acceleration']].plot(kind = 'bar');
# Out:
# C:\Users\bldea0\AppData\Local\Temp\ipykernel_13092\2514051022.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('model_year').mean()[['acceleration']].plot(kind = 'bar');

# %%
df.plot(x = 'weight', y = 'mpg', kind = 'scatter')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
df.groupby('cylinders').mean().sort_values('acceleration')[['acceleration']].plot(kind = 'bar')
# Out:
# C:\Users\bldea0\AppData\Local\Temp\ipykernel_13092\4081279867.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('cylinders').mean().sort_values('acceleration')[['acceleration']].plot(kind = 'bar')
# <Axes: xlabel='cylinders'>
