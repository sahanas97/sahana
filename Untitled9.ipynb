# %%
import pandas as pd
df=pd.read_csv('dataset/placement.csv')
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(data=df,x='cgpa',y='placement_exam_marks',hue='placed')
# Out:
# <Axes: xlabel='cgpa', ylabel='placement_exam_marks'>

# %%
x=df[['placement_exam_marks','placed']]
x
# Out:
#      placement_exam_marks  placed
# 0                    26.0       1
# 1                    38.0       1
# 2                    40.0       1
# 3                     8.0       1
# 4                    17.0       0
# ..                    ...     ...
# 995                  44.0       1
# 996                  65.0       1
# 997                  34.0       0
# 998                  46.0       1
# 999                  10.0       1
#
# [1000 rows x 2 columns]

# %%
y=df['cgpa']

y
# Out:
# 0      7.19
# 1      7.46
# 2      7.54
# 3      6.42
# 4      7.23
#        ...
# 995    8.87
# 996    9.12
# 997    4.89
# 998    8.62
# 999    4.90
# Name: cgpa, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,df[['cgpa']],test_size=0.2)

# %%
x_train
# Out:
#      placement_exam_marks  placed
# 350                  70.0       0
# 444                  14.0       1
# 36                   16.0       1
# 674                  31.0       1
# 608                  16.0       1
# ..                    ...     ...
# 410                  37.0       1
# 755                  26.0       0
# 2                    40.0       1
# 379                  65.0       0
# 973                  37.0       1
#
# [800 rows x 2 columns]

# %%
x_test
# Out:
#      placement_exam_marks  placed
# 192                  38.0       0
# 126                  37.0       0
# 333                  20.0       1
# 321                  47.0       0
# 329                  35.0       0
# ..                    ...     ...
# 496                  35.0       1
# 488                  43.0       0
# 258                   6.0       1
# 295                  64.0       0
# 202                  48.0       1
#
# [200 rows x 2 columns]

# %%
y_train
# Out:
#      cgpa
# 350  7.21
# 444  6.66
# 36   6.85
# 674  6.73
# 608  7.33
# ..    ...
# 410  7.36
# 755  6.94
# 2    7.54
# 379  7.37
# 973  6.10
#
# [800 rows x 1 columns]

# %%
y_test
# Out:
#      cgpa
# 192  6.67
# 126  7.16
# 333  6.74
# 321  6.82
# 329  7.30
# ..    ...
# 496  7.52
# 488  6.75
# 258  6.12
# 295  6.02
# 202  6.51
#
# [200 rows x 1 columns]

# %%
#Fitting the MLR model to the training set:  
from sklearn.linear_model import LinearRegression  
lr= LinearRegression()  
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([[6.93466933],
#        [6.93499581],
#        [7.00162154],
#        [6.931731  ],
#        [6.93564877],
#        [6.93728117],
#        [7.00358042],
#        [7.0006421 ],
#        [6.94185189],
#        [7.00260098],
#        [6.92944564],
#        [7.00260098],
#        [6.93336341],
#        [6.9973773 ],
#        [6.97974737],
#        [6.93499581],
#        [7.00194802],
#        [7.00031562],
#        [6.99803026],
#        [6.93336341],
#        [6.93532229],
#        [6.99313305],
#        [6.99966266],
#        [7.00194802],
#        [6.93075156],
#        [6.93695469],
#        [7.00586578],
#        [6.93597525],
#        [7.00096858],
#        [6.91769236],
#        [7.00488634],
#        [7.00194802],
#        [6.93924005],
#        [6.94185189],
#        [6.93924005],
#        [7.00260098],
#        [6.93891357],
#        [7.0039069 ],
#        [6.9973773 ],
#        [6.94087245],
#        [6.93728117],
#        [6.99313305],
#        [6.98823585],
#        [6.98758289],
#        [6.99705082],
#        [6.94217837],
#        [6.93924005],
#        [6.99933618],
#        [7.00455986],
#        [6.99378601],
#        [6.98954177],
#        [7.00194802],
#        [7.00260098],
#        [6.93271044],
#        [6.99835674],
#        [7.00096858],
#        [6.92879268],
#        [6.94479021],
#        [6.93597525],
#        [7.00096858],
#        [7.00292746],
#        [6.93695469],
#        [6.94054597],
#        [7.00455986],
#        [6.92161012],
#        [6.99607138],
#        [6.92650732],
#        [7.0055393 ],
#        [6.93662821],
#        [6.93858709],
#        [7.00455986],
#        [6.99770378],
#        [6.94119893],
#        [7.00096858],
#        [6.94250485],
#        [6.99313305],
#        [6.93434285],
#        [6.94217837],
#        [6.9973773 ],
#        [6.93303693],
#        [6.94381077],
#        [7.0022745 ],
#        [6.93728117],
#        [7.00358042],
#        [6.97746201],
#        [7.00260098],
#        [6.9973773 ],
#        [7.00096858],
#        [7.00619226],
#        [6.93989301],
#        [6.94381077],
#        [6.93858709],
#        [6.94315781],
#        [7.00096858],
#        [6.93924005],
#        [7.00586578],
#        [6.99803026],
#        [6.99639786],
#        [6.92748676],
#        [7.00194802],
#        [6.92389548],
#        [6.94283133],
#        [6.98170625],
#        [6.98170625],
#        [6.99411249],
#        [6.93205748],
#        [6.92226308],
#        [6.9268338 ],
#        [7.00488634],
#        [6.94315781],
#        [6.94315781],
#        [6.98235921],
#        [6.99215361],
#        [7.00260098],
#        [7.0022745 ],
#        [6.93597525],
#        [6.94119893],
#        [6.98497105],
#        [6.94413725],
#        [7.00815114],
#        [6.92977212],
#        [6.94315781],
#        [6.93793413],
#        [6.98758289],
#        [6.99117417],
#        [6.91442756],
#        [6.99313305],
#        [6.93597525],
#        [6.92618084],
#        [6.931731  ],
#        [6.99770378],
#        [7.00292746],
#        [7.00292746],
#        [6.93891357],
#        [6.92487492],
#        [7.00292746],
#        [6.9973773 ],
#        [6.93630173],
#        [7.00162154],
#        [6.99052121],
#        [6.94119893],
#        [6.99345953],
#        [6.94185189],
#        [7.00292746],
#        [7.00455986],
#        [6.93826061],
#        [6.98464457],
#        [6.99966266],
#        [6.93924005],
#        [6.9990097 ],
#        [7.0022745 ],
#        [6.93891357],
#        [7.00619226],
#        [6.93728117],
#        [6.94152541],
#        [6.99182713],
#        [6.92781324],
#        [6.94217837],
#        [7.0022745 ],
#        [6.93924005],
#        [6.99639786],
#        [6.94087245],
#        [6.9957449 ],
#        [6.98692993],
#        [6.94185189],
#        [7.00488634],
#        [6.99019473],
#        [7.00129506],
#        [7.0022745 ],
#        [7.00129506],
#        [6.93271044],
#        [7.00129506],
#        [7.00260098],
#        [7.0022745 ],
#        [6.93597525],
#        [6.93303693],
#        [6.93140452],
#        [7.0022745 ],
#        [6.9268338 ],
#        [7.00358042],
#        [6.92422196],
#        [7.00292746],
#        [6.99378601],
#        [6.93532229],
#        [6.94152541],
#        [7.00423338],
#        [6.93793413],
#        [6.9957449 ],
#        [6.99019473],
#        [6.93826061],
#        [7.00194802],
#        [6.93662821],
#        [6.99607138],
#        [6.93924005],
#        [7.00455986],
#        [6.99672434],
#        [6.93303693],
#        [7.00619226],
#        [6.92618084],
#        [6.99248009]])

# %%
print('train score:',lr.score(x_train,y_train))
print('test score:',lr.score(x_test,y_test))
# Out:
# train score: 0.002574990126140375
# test score: -0.008075367680040024
